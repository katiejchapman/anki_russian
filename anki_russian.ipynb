# %%
from forvo import get_forvo_page,pronunciation_for_li
from bs4 import BeautifulSoup, element

# %%
def pronunciation_for_li(element: element.Tag):
    # -> Optional[Pronunciation]:
    """Pronunciation object from its <li> element

    Returns an optional Pronunciation object from a
    <li> element that contains the required info.

    Returns
    -------
    Pronunciation object, or None
    """
    info_span = element.find("span", {"class": "info"})
    print(info_span)
    if info_span is not None:
        user = user_from_info_span(info_span)
    votes = num_votes_from_li(element)
    url = audio_link_for_li(element)
    if url is not None:
        pronunciation = Pronunciation(user, votes, url)
        return pronunciation
    return None

# %%
ru_pronunciation_list = get_forvo_page("https://forvo.com/word/%D0%BF%D1%80%D0%BE%D1%85%D0%BB%D0%B0%D0%B4%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9_%D0%BD%D0%B0%D0%BF%D0%B8%D1%82%D0%BE%D0%BA/")
print("done")

# %%
pronunciations = []
for li in ru_pronunciation_list.find_all("li"):
    print(li)
    pronunciation = pronunciation_for_li(li)
    pronunciations.append(pronunciation)
    
use_p  = max(pronunciations) if len(pronunciations) > 1 else pronunciations[0]

print(use_p)
# Out:
# <li class="pronunciation li-active">
# <div class="play icon-size-xl" id="play_7474894" onclick="Play(7474894,'MTAwNDQ1NzIvMTM4LzEwMDQ0NTcyXzEzOF81NDA2MDUzLm1wMw==','MTAwNDQ1NzIvMTM4LzEwMDQ0NTcyXzEzOF81NDA2MDUzLm9nZw==',false,'Zi8xL2YxXzEwMDQ0NTcyXzEzOF81NDA2MDUzLm1wMw==','Zi8xL2YxXzEwMDQ0NTcyXzEzOF81NDA2MDUzLm9nZw==','h','прохладительный напиток','Russian');return false;" title="Listen прохладительный напиток pronunciation">прохладительный напиток pronunciation<div class="audio"><div class="bar-1"></div><div class="bar-2"></div><div class="bar-3"></div></div><div class="wave"><div class="six"></div><div class="five"></div><div class="four"></div><div class="three"></div><div class="two"></div><div class="one"></div></div></div>
# <span class="info" style="">
# 			Pronunciation by
#
# 							<span class="ofLink" data-p1="aHR0cHM6Ly9mb3J2by5jb20vdXNlci8jQCMv" data-p2="tehpoison">
# 						tehpoison
# 							</span>
# </span>
# <span class="from">(Male from Ukraine)</span>
# <span class="responsive-gender-country">Male from Ukraine</span>
# <div class="more">
# <span class="pronunciationMoreMenu"></span>
# <div class="main_actions">
# <div class="content">
# <div class="title">
# 						Pronunciation by
# 						<span class="active">
# 							tehpoison
# 						</span>
# </div>
# <div class="extra-info">
# <p class="profile">
# <span class="ofLink statusGrey" data-p1="aHR0cHM6Ly9mb3J2by5jb20vdXNlci8jQCMv" data-p2="tehpoison">
# 									User information
# 								</span>
# </p>
# <p class="followed" id="followed_7474894">
# <span class="ofLink statusGrey follow follow-user" data-p1="aHR0cHM6Ly9mb3J2by5jb20vZm9sbG93ZWQtdXNlcnMvI0AjLw" data-p2="7474894" title="Follow tehpoison's pronunciations in this language.">
# 							Follow
# 					</span>
# </p>
# </div>
# <div class="info" style="">
# <p class="votes votes_ru_content" id="word_rate_7474894">
# <span class="num_votes">
# <span class="ofLink statusGrey" data-id="7474894">1 votes</span>
# </span>
# <span class="vote_good ofLink statusGrey" data-p1="aHR0cHM6Ly9mb3J2by5jb20vdm90ZS8jQCMvQCNALw" data-p2="7474894" data-p3="good" onclick="">Good</span>
# <span class="vote_wrong ofLink statusGrey" data-p1="aHR0cHM6Ly9mb3J2by5jb20vdm90ZS8jQCMvQCNALw" data-p2="7474894" data-p3="report" onclick="">Bad</span>
# </p>
# <p class="favourite" id="word_favorite_7474894">
# <span class="ofLink statusGrey" data-p1="aHR0cHM6Ly9mb3J2by5jb20vZmF2b3JpdGUvI0AjLw" data-p2="7474894">Add to favorites</span>
# </p>
# <p class="download">
# <span class="ofLink statusGrey" data-p1="aHR0cHM6Ly9mb3J2by5jb20vZG93bmxvYWQvbXAzLyNAIy9AI0AvIyNAQA" data-p2="%D0%BF%D1%80%D0%BE%D1%85%D0%BB%D0%B0%D0%B4%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9_%D0%BD%D0%B0%D0%BF%D0%B8%D1%82%D0%BE%D0%BA" data-p3="ru" data-p4="7474894" title="Download прохладительный напиток MP3 pronunciation">Download MP3</span>
# </p>
# <div class="report">
# <span class="ofLink statusGrey" data-p1="aHR0cHM6Ly9mb3J2by5jb20vd29yZC1yZXBvcnQvI0AjL0AjQC8" data-p2="%D0%BF%D1%80%D0%BE%D1%85%D0%BB%D0%B0%D0%B4%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9_%D0%BD%D0%B0%D0%BF%D0%B8%D1%82%D0%BE%D0%BA" data-p3="7474894">
# 							Report
# 							</span>
# </div>
# </div>
# </div>
# </div>
# <div class="fade"></div>
# </div>
# </li>
# <span class="info" style="">
# 			Pronunciation by
#
# 							<span class="ofLink" data-p1="aHR0cHM6Ly9mb3J2by5jb20vdXNlci8jQCMv" data-p2="tehpoison">
# 						tehpoison
# 							</span>
# </span>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/75/6475tpjx4_10wfz6p7hnp95w0000gn/T/ipykernel_14730/907038891.py in <module>
#       2 for li in ru_pronunciation_list.find_all("li"):
#       3     print(li)
# ----> 4     pronunciation = pronunciation_for_li(li)
#       5     pronunciations.append(pronunciation)
#       6
#
# /var/folders/75/6475tpjx4_10wfz6p7hnp95w0000gn/T/ipykernel_14730/192665742.py in pronunciation_for_li(element)
#      13     print(info_span)
#      14     if info_span is not None:
# ---> 15         user = user_from_info_span(info_span)
#      16     votes = num_votes_from_li(element)
#      17     url = audio_link_for_li(element)
#
# NameError: name 'user_from_info_span' is not defined

# %%
__version__ = 0.9
# accept word as either argument or on stdin
try:
   raw_word = sys.argv[1]
except IndexError:
   raw_word = sys.stdin.read()

raw_word = raw_word.replace(" ", "_").strip()
word = urllib.parse.quote(raw_word)
url =  f'https://en.wiktionary.org/wiki/{word}#Russian'

hn = [HardwareType.COMPUTER.value]
user_agent_rotator = UserAgent(hardware_types=hn,limit=20)
user_agent = user_agent_rotator.get_random_user_agent()
headers = {'user-agent': user_agent}
try:
   response = urlopen(Request(url, headers = headers))
except urllib.error.HTTPError as e:
   if e.code == 404:
      print("Error - no such word")
   else:
      print(f"Error: status {e.code}")
   sys.exit(1)

# first extract the Russian content because
# we may have other languages. This just
# simplifies the parsing for the headword
new_soup = BeautifulSoup('', 'html.parser')
soup = BeautifulSoup(response.read(), 'html.parser')
for h2 in soup.find_all('h2'):
   for span in h2.children:
      try:
         if 'Russian' in span['id']:
            new_soup.append(copy.copy(h2))
            # capture everything in the Russian section
            for curr_sibling in h2.next_siblings:
               if curr_sibling.name == "h2":
                  break
               else:
                  new_soup.append(copy.copy(curr_sibling))
            break
      except:
         pass

# use the derived soup to pick out the headword from
# the Russian-specific content
headwords = []
for strong in new_soup.find_all('strong'):
   node_lang = strong.get('lang')
   node_class = strong.get('class')
   if node_lang == "ru":
      if "Cyrl" in node_class:
         if "headword" in node_class:
            raw_headword = strong.text
            headwords.append(raw_headword)

try:
   print(headwords[0])
   sys.exit(0)
except SystemExit:
   # this just avoids triggering an exception due
   # to a normal exit
   pass
except IndexError:
   # we didn't find any words
   print("Error")
   sys.exit(1)
